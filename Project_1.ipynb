# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dataset = pd.read_excel("Superstore_USA.xlsx")

# %%
dataset.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
dataset.isnull().sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     72
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %%
dataset['Product Base Margin'].fillna(dataset['Product Base Margin'].mean(),inplace = True)

# %%
dataset.isnull().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# dtype: int64

# %%
dataset.shape
# Out:
# (9426, 24)

# %% [markdown]
# # Order Priority

# %%
dataset['Order Priority'].value_counts()
# Out:
# Order Priority
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1804
# Critical            1
# Name: count, dtype: int64

# %%
dataset['Order Priority'].unique()
# Out:
# array(['Not Specified', 'High', 'Medium', 'Low', 'Critical', 'Critical '],
#       dtype=object)

# %%
dataset['Order Priority'] = dataset['Order Priority'].replace("Critical ","Critical")

# %%
dataset['Order Priority'].value_counts()
# Out:
# Order Priority
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1805
# Name: count, dtype: int64

# %%
plt.figure(figsize = (5,4))
sns.countplot(data = dataset,x = 'Order Priority')
plt.title("Count of Order Priority",fontdict = {'fontsize':15,'color':'b','fontweight':'bold'})
plt.savefig(fname = "Count of Order Priority.jpg",dpi = 800,bbox_inches = 'tight')
plt.show()

# %% [markdown]
# # Ship Mode

# %%
dataset['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: count, dtype: int64

# %%
x = dataset['Ship Mode'].value_counts().index
y = dataset['Ship Mode'].value_counts().values

# %%
# plt.figure(figsize = (5,4))
plt.pie(y,labels = x,startangle = 60,autopct = "%0.2f%%")
plt.title("Pie chart of Shipping Modes",fontdict = {'fontsize':15,'color':'g','fontweight':'bold'})
plt.legend(bbox_to_anchor = (1,1))
plt.savefig("Pie chart of Shipping modes.jpg",dpi = 800,bbox_inches = 'tight')
plt.show()

# %%
sns.countplot(data = dataset,x = 'Ship Mode',hue = 'Product Category')
plt.title("Shipping modes & Product categories",fontdict = {'fontsize':15,'color':'b','fontweight':'bold'})
plt.xlabel("Ship Mode",fontdict = {'fontsize':15,'color':'m'})
plt.ylabel("Count",fontdict = {'fontsize':15,'color':'m'})
plt.savefig("Shipping modes & Product categories.jpg",dpi = 800,bbox_inches = 'tight')
plt.show()

# %% [markdown]
# # Customer Segment

# %%
sns.countplot(data = dataset,x = 'Customer Segment')
plt.show()

# %% [markdown]
# # Product Category

# %%
sns.countplot(data = dataset,x = 'Product Category')
plt.show()

# %% [markdown]
# # Product Sub-Category

# %%
sns.countplot(data = dataset,x = 'Product Category',hue = 'Product Sub-Category')
plt.show()

# %%
plt.figure(figsize = (7,6))
sns.countplot(data = dataset[dataset["Product Category"] == "Office Supplies"],x = "Product Category",hue = 'Product Sub-Category')
plt.show()

# %%
plt.figure(figsize = (7,5))
sns.countplot(data = dataset[dataset["Product Category"] == "Technology"],x = "Product Category",hue = "Product Sub-Category")
plt.show()

# %%
sns.countplot(data = dataset[dataset["Product Category"] == "Furniture"],x = "Product Category",hue = "Product Sub-Category")
plt.show()

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9426 non-null   float64
#  14  Region                9426 non-null   object
# ...

# %%
dataset['Order year'] = dataset['Order Date'].dt.year

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9426 non-null   float64
#  14  Region                9426 non-null   object
# ...

# %%
dataset['Order year'].value_counts()
# Out:
# Order year
# 2013    3054
# 2012    2241
# 2011    2179
# 2010    1952
# Name: count, dtype: int64

# %%
sns.countplot(data = dataset,x = 'Order year')
plt.title("Orders & Years",fontdict = {'fontsize':15,'color':'b','fontweight':'bold'})
plt.show()

# %%
sns.barplot(data = dataset,x = "Product Category",y = "Profit",estimator = 'sum')
plt.title("Products Category & Profits",fontdict = {'fontsize':15,'color':'b','fontweight':'bold'})
plt.show()

# %%
dataset['State or Province'].value_counts()[:5]
# Out:
# State or Province
# California    1021
# Texas          646
# Illinois       584
# New York       574
# Florida        522
# Name: count, dtype: int64

# %%
sns.barplot(data = dataset,x = "Product Category",y = "Product Base Margin",estimator = 'sum')
plt.title("Products Category & Margin",fontdict = {'fontsize':15,'color':'b','fontweight':'bold'})
plt.show()
